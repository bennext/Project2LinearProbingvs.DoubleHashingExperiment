# %%
import random


class TableEntry ( ):

    def __init__(self, key, value):
        pass
    def get_key(self):
        pass
    def get_value(self):
        pass
    def set_value(self, value):
        pass
    def is_in_table(self):
        pass
    def set_to_removed(self):
        pass
    def is_removed(self):
        pass
     

class HashTableWithCount ( ):

    def __init__(self, initial_capacity ): # =(insert_your_choice_here)):
        pass
    def get_next_prime(self, n):
        pass
    def is_prime(self, n):
        pass
    def check_size(self, size):
        pass
    def get_hash_index(self, key):
        pass
    def is_hash_table_too_full(self):
        pass
    def enlarge_hash_table(self):
        pass
    def reset_probe_count(self):
        pass
    def get_probes(self):
        pass
    

 
class LinearProbingWithCount ( ):

    def probe(self, index, key):
        pass
    def locate(self, index, key):
        pass
    def add(self, key, value):
        pass
    def remove(self, key):
        pass
    def get_value(self, key):
        pass
    def contains(self, key):
        pass
    def is_empty(self):
        pass
    def get_size(self):
        pass
    def clear(self):
        pass
    

 
class DoubleHashingWithCount ( ):

    def probe(self, index, key):
        pass
    def locate(self, index, key):
        pass
    def add(self, key, value):
        pass
    def remove(self, key):
        pass
    def get_value(self, key):
        pass
    def contains(self, key):
        pass
    def is_empty(self):
        pass
    def get_size(self):
        pass
    def clear(self):
        pass
    

 
class GetStatistics ( ):

    def main():
        pass
    def choose_100_names_and_add(linear_ht, double_ht, names):
        pass
    def get_1000_names(names):
        pass
    def get_10000_names(names):
        pass
    def search_for_100_names(linear_ht, double_ht, names):
        pass
    
GetStatistics.main()


def a_1000_names():
    names_list = []
    for num in range(1000):
        a_name = ""
        a_name = a_name +  str(chr( random.randrange(65, 91))) + str(chr( random.randrange( 97, 123)) + str(chr( random.randrange( 97, 123))) +str (num) )  
        names_list.append(a_name)
    return names_list


the_list_of_names = a_1000_names()
print (the_list_of_names)
print (len(the_list_of_names))

print (chr(random.randrange(89, 91)))
# Out:
# ['Nmd0', 'Dys1', 'Meo2', 'Dvt3', 'Cff4', 'Yig5', 'Bqo6', 'Etp7', 'Oqi8', 'Gmw9', 'Roh10', 'Lra11', 'Grd12', 'Svs13', 'Jvn14', 'Gwu15', 'Nfo16', 'Jnw17', 'Ruj18', 'Zfd19', 'Ymk20', 'Kgq21', 'Olt22', 'Dmr23', 'Zhl24', 'Swy25', 'Mip26', 'Weh27', 'Rjh28', 'Fih29', 'Pib30', 'Fle31', 'Xnl32', 'Mbc33', 'Rvx34', 'Buq35', 'Qxw36', 'Toj37', 'Shm38', 'Eqh39', 'Coc40', 'Vry41', 'Yfu42', 'Vlz43', 'Dhn44', 'Ift45', 'Ifg46', 'Xsf47', 'Mjn48', 'Zfu49', 'Slv50', 'Kap51', 'Byy52', 'Inn53', 'Wxo54', 'Ytl55', 'Awd56', 'Bvo57', 'Dua58', 'Nbm59', 'Yzi60', 'Jph61', 'Hwy62', 'Eyf63', 'Vam64', 'Phi65', 'Vcc66', 'Scl67', 'Ydu68', 'Sag69', 'Vma70', 'Ugm71', 'Hbb72', 'Rxo73', 'Yrb74', 'Wmu75', 'Rha76', 'Bii77', 'Etf78', 'Cqi79', 'Nnc80', 'Vzu81', 'Vpm82', 'Prg83', 'Zvo84', 'Frm85', 'Cce86', 'Ukt87', 'Vov88', 'Txh89', 'Mbt90', 'Rlm91', 'Wua92', 'Gsk93', 'Rpd94', 'Pzl95', 'Nrx96', 'Wpc97', 'Xyj98', 'Ksp99', 'Imw100', 'Rxk101', 'Zuj102', 'Uwx103', 'Yrb104', 'Xig105', 'Cmh106', 'Hil107', 'Ehp108', 'Yvx109', 'Aqy110', 'Acy111', 'Fvq112', 'Row113', 'Dby114', 'Kzi115', 'Fbc116', 'Stu117', 'Feg118', 'Xtv119', 'Yne120', 'Sll121', 'Bog122', 'Gco123', 'Vxv124', 'Kmn125', 'Nqp126', 'Cwn127', 'Dsz128', 'Wii129', 'Vem130', 'Ixs131', 'Yas132', 'Isn133', 'Kbw134', 'Gqt135', 'Pik136', 'Gis137', 'Mfq138', 'Cyz139', 'Dca140', 'Nok141', 'Xtx142', 'Btr143', 'Bpp144', 'Twx145', 'Yep146', 'Cep147', 'Qck148', 'Ngt149', 'Vzq150', 'Rxg151', 'Cjw152', 'Rfd153', 'Vox154', 'Snq155', 'Qye156', 'Khb157', 'Vgs158', 'Arb159', 'Vnk160', 'Klm161', 'Upq162', 'Mge163', 'Zml164', 'Cyd165', 'Ljn166', 'Rev167', 'Qgf168', 'Pxx169', 'Zei170', 'Giv171', 'Hal172', 'Xkj173', 'Aoi174', 'Mhk175', 'Crg176', 'Epm177', 'Owt178', 'Nkh179', 'Uzk180', 'Fug181', 'Riw182', 'Onl183', 'Yyq184', 'Fvk185', 'Cpd186', 'Orp187', 'Xol188', 'Pcg189', 'Pza190', 'Oov191', 'Qcs192', 'Tvo193', 'Rwd194', 'Pmi195', 'Qjh196', 'Mce197', 'Zsm198', 'Hie199', 'Zvv200', 'Sdj201', 'Vmw202', 'Hgc203', 'Uvi204', 'Bop205', 'Mdr206', 'Wcp207', 'Roj208', 'Wne209', 'Xbc210', 'Stg211', 'Fsy212', 'Irs213', 'Vme214', 'Mie215', 'Nob216', 'Cdg217', 'Fbx218', 'Xhd219', 'Zof220', 'Srp221', 'Gje222', 'Fpx223', 'Toi224', 'Rep225', 'Fmg226', 'Krc227', 'Izt228', 'Ykt229', 'Kxv230', 'Gst231', 'Izg232', 'Gnm