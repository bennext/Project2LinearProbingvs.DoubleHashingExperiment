# %%
import random
from hashingTemplate import *

# Class to define entries in the HashTable

import random
import math

class TableEntry:
    def __init__(self, key, value):
        self.key = key
        self.value = value
        self.in_table = True

    def get_key(self):
        return self.key

    def get_value(self):
        return self.value

    def set_value(self, value):
        self.value = value

    def is_in_table(self):
        return self.in_table

    def set_to_removed(self):
        self.key = None
        self.value = None
        self.in_table = False

    def is_removed(self):
        return (self.key is None) and (self.value is None) and not self.in_table

# %%
# Hash Table implementation
class HashTableWithCount ( OpenAddressingHashTable ):
    with_count = 0

    def __init__(self, initial_capacity ): # =(insert_your_choice_here)):
        super().__init__(self, initial_capacity )
        pass

    #given a number, return a prime number that's bigger 
    def get_next_prime(self, n):
        o = n + 1
        
        if 0 == o % 2:
            o += 1

        while not self.is_prime(o):
            o += 2
        
        return o

    # checks prime, returns true or false 
    def is_prime(self, n):
        i = 3
        found_factor = False

        if n % 2 == 0:
            found_factor = True

        while i <= n ** 0.5 and not found_factor:
            
            # print (i)
            if n % i == 0:
                found_factor = True
            i += 2
                
        return not found_factor


    #It is a function that allows you to pass in the size of a hash table and verify it against a max size that you create, 
    # 4then if its bigger than that that max size, it returns a ValueError(“Size exceeds maximum allowable size”). 
    # If you have a max size defined to avoid it growing too large when you use enlarge_hash_table, 
    # you could call check_size when you enlarge it. 
    # Imagine reading in a very large amount of data and you don’t want your table to get bigger than a certain size for efficiency reasons. 
    # You’d rather throw an error if that happens then let it grow.
    # You don’t necessarily have to use check_size for this project 
    # but its a good function to have in place in the essence of generalization of the 
    # class to be used in multiple projects with different requirements
    def check_size(self, size):
        if size > len(self.table)  :
            return "Size exceeds maximum allowable size"
        pass

    def get_hash_index(self, key):
        return abs(hash(key))
        pass
    def is_hash_table_too_full(self):
        pass
    def enlarge_hash_table(self):
        pass
    def reset_probe_count(self):
        pass
    def get_probes(self):
        pass

# %%
# Inherits HashTableWithCount using linear probing 
class LinearProbingWithCount (HashTableWithCount ):
    # Your linear probing hashing equation will be: 
    # index = (index + 1) % self.table_size

    count = 0

    #    probe (used within add to return the new index after probe)
    def probe(self, index, key):
        return (self.hashKey(key) + index) % len(self.table)
        pass
        return index
    
    def locate(self, index, key):
        pass
    def add(self, key, value):
        pass
    def remove(self, key):
        super(self, key)
        pass
    def get_value(self, key):
        pass
    def contains(self, key):
        pass
    def is_empty(self):
        pass
    def get_size(self):
        pass
    def clear(self):
        pass

# %%
# Inherits HashTableWithCount using double hashing
class DoubleHashingWithCount(HashTableWithCount):
    def primary_hash(self, key):
        """First hash function."""
        return hash(key) % self.table_size
    
    def secondary_hash(self, key):
        """Second hash function to calculate step size."""
        return 1 + (hash(key) % (self.table_size - 1))

    def probe(self, index, key):
        # code here
        return (self.hashKey(key) + index * self.h2(key)) % len(self.table)
        return index

    # code here
    
    def locate(self, index, key):
        pass
    def add(self, key, value):
        pass
    def remove(self, key):
        super(self, key)
        pass
    def get_value(self, key):
        pass
    def contains(self, key):
        pass
    def is_empty(self):
        pass
    def get_size(self):
        pass
    def clear(self):
        pass

# %%
# Where you run the experiment. 
class GetStatistics ( ):

    def main():
        print("main run")
        pass

    def choose_100_names_and_add(linear_ht, double_ht, names):
        for a in range(100):   
            linear_ht.add(names[random.randrange(1000)])
            double_ht.add(names[random.randrange(1000)])

        pass

    def get_1000_names(names):
        pass
    def get_10000_names(names):
        pass
    def search_for_100_names(linear_ht, double_ht, names):
        pass
    
if __name__ == "__main__":
    GetStatistics.main()
##

# creates a list of 1000 random unique names  
def a_1000_names():
    names_list = []
    for num in range(1000):
        a_name = ""
        a_name = a_name +  str(chr( random.randrange(65, 91))) + str(chr( random.randrange( 97, 123)) + str(chr( random.randrange( 97, 123))) +str (num) )  
        names_list.append(a_name)
    return names_list

##
print("start")

GetStatistics.main()

the_list_of_names = a_1000_names()
# print (the_list_of_names)
# print (len(the_list_of_names))

# print (chr(random.randrange(89, 91)))
a_random_int = random.randrange(1000)

print (a_random_int, the_list_of_names[a_random_int])

# create an empty list for constructor 
constructor_list = [None] * 1000
# print (constructor_list)

new_entry = TableEntry("key", "value")



print("end")
